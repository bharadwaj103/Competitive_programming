# %% [markdown]
# <a href="https://colab.research.google.com/github/bharadwaj103/Competitive_programming/blob/main/Week2_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def subset_sum(arr, target, index=0, current_sum=0):
    if current_sum == target:
        return True
    if current_sum > target or index == len(arr):
        return False
    if subset_sum(arr, target, index + 1, current_sum + arr[index]):
        return True
    if subset_sum(arr, target, index + 1, current_sum):
        return True
    return False
n = int(input())
arr = list(map(int, input().split()))
target = int(input())
print(subset_sum(arr, target))
# Out:
# 5
# 3 34 4 12 5
# 9
# True
